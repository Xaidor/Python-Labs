# %%
# Create your favorite letter using matplotlib.pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,1,1,3,1,3]
y = [0,5,2.7,5,2.7,0]

# %%
plt.plot(5,5)
plt.plot(x,y,"sc-")
